# %%
# %%html
# <html>
#     <head>
#         <script type="text/javascript"></script>
#         <meta charset="utf-8" /></script>
#         <script src="https://www.gstatic.com/charts/loader.js"></script>
#         <script src="https://code.jquery.com/jquery-3.4.1.js"></script>
#         <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
#         <h1>Association of Lung Cancer Imaging With Genomic and Clinical Data</h1>
#         <script type="text/javascript"></script>
#         <style>
#             h1 {
#                 padding: 60px;
#                 text-align: center;
#                 background: #1ABC9C;
#                 color: white;
#                 font-size: 30px;
#                 }
#             .navbar {
#                 overflow: hidden;
#                 background-color: #008080;
#                 font-family: Arial, Helvetica, sans-serif;
#                 }
#             .navbar a {
#                 float: left;
#                 font-size: 16px;
#                 color: white;
#                 text-align: center;
#                 padding: 14px 16px;
#                 text-decoration: none;
#                 }
#             .dropdown {
#                 float: left;
#                 overflow: hidden;
#                 }
#                 .dropdown .dropbtn {
#                 cursor: pointer;
#                 font-size: 16px;
#                 border: none;
#                 outline: none;
#                 color: white;
#                 padding: 14px 16px;
#                 background-color: inherit;
#                 font-family: inherit;
#                 margin: 0;
#                 }
#                 .navbar a:hover, .dropdown:hover .dropbtn, .dropbtn:focus {
#                 background-color: #008B8B;
#                 }
#                 .show {
#                 display: block;
#                 }
#             * {box-sizing: border-box;}
#             .row {
#                 margin-left:-5px;
#                 margin-right:-5px;
#                 }
#             .column {
#                 float: left;
#                 width: 40%;
#                 padding: 15px;
#                 }
#             /* Clearfix (clear floats) */
#                 .row::after {
#                 content: "";
#                 clear: both;
#                 display: table;
#                 }
#             table {
#                 border-collapse: collapse;
#                 border-spacing: 0;
#                 width: 100%;
#                 border: 1px solid #ddd;
#                 }
#             th, td {
#                 text-align: left;
#                 padding: 16px;
#                 border: 1px solid black;
#                 overflow:hidden; white-space:nowrap
#                 }
#             tr:nth-child(even) {
#                 background-color: #F2F2F2;
#                 }
#             .center {
#                 margin-left: auto;
#                 margin-right: auto;
#                 }
#         </style>
#     </head>
#     </head>
#     <body>
#         <div class="navbar">
#             <a href="#home">Home</a>
#             <a href="#DATA">Data</a>
#             <a href="#PCGA">PCGA</a>
#             <a href="#TCGA">TCGA</a>
#             <a href="#UMAP">UMAP</a>
#             <a href="#help">Help</a>
#         </div>
#         <p>Pre-Cancer Genome Atlas (PCGA) characterize the molecular alterations in premalignant lesions and the surrounding microenvironment throughout the stages of progression towards or regression from invasive cancer.  This portal collects pathologic data  about annotation based on whole-slide images (WSIs)  to distinguish between lung squamous bronchial premalignant lesions and malignant lesions </p>
#         <b>Sample Type: </b>
#         <select name="sampletype" id="sampletype">
#         <option value="" selected="selected">Choose the Sample type </option>
#         <option value="Biopsy">Biopsy</option>
#         <option value="Brush">Brush</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         <b>Cohort: </b>
#         <select name="cohorttype" id="cohorttype">
#         <option value="" selected="selected">Choose the Cohort type </option>
#         <option value="Discovery">Discovery</option>
#         <option value="Validation">Validation</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         <b>Gender: </b>
#         <select name="sex" id="sex">
#         <option value="" selected="selected">Choose the Gender type </option>
#         <option value="Male">Male</option>
#         <option value="Female">Female</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         <b>Genomic Smoking Status: </b>
#         <select name="status" id="status">
#         <option value="" selected="selected">Choose the Smoking Status type </option>
#         <option value="Current">Current</option>
#         <option value="Former">Former</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         <b>Previous Lung Cancer History: </b>
#         <select name="LC_history" id="LC_history">
#         <option value="" selected="selected">Choose the Lung Cancer History type </option>
#         <option value="Yes">Yes</option>
#         <option value="No">No</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         <b>High Risk Lung Cancer Job: </b>
#         <select name="LC_job" id="LC_job">
#         <option value="" selected="selected">Choose Lung Cancer Job type </option>
#         <option value="Yes">Yes</option>
#         <option value="No">No</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         <b>Asbestos Exposure: </b>
#         <select name="AB_exp" id="AB_exp">
#         <option value="" selected="selected">Choose the Asebestos Exposure type </option>
#         <option value="Yes">Yes</option>
#         <option value="No">No</option>
#         <option value="">- Both -</option>
#         </select><br></br>
#         <input type="button" id="save_value" name="save_value" value="Save"/>
#         <div id ="write1"></div>
#         <div id ="result_table" style="height:700px; width:100%; overflow-y: scroll;overflow-x: scroll;"></div>
#     <script>
#         $(document).ready(function() {
#             $('#save_value').click(function() {
#                     $("#write1").empty();
#                     var sampletype = $("#sampletype").val();
#                     let cohorttype = $("#cohorttype").val();
#                     let sex = $("#sex").val();
#                     let status = $("#status").val();
#                     let LC_history = $("#LC_history").val();
#                     let LC_job = $("#LC_job").val();
#                     let AB_exp = $("#AB_exp").val();
#                     $("#write1").append(`<h3 style="color:#008080">Selcted Filters are:</p>`);
#                     $("#write1").append(`<p>Sample Type: ${sampletype}</p>`);
#                     $("#write1").append(`<p>Cohort Type: ${cohorttype}</p>`);
#                     $("#write1").append(`<p>Gender: ${sex}</p>`);
#                     $("#write1").append(`<p>Genomic Smoking Status: ${status}</p>`);
#                     $("#write1").append(`<p>Previous Lung Cancer History: ${LC_history}</p>`);
#                     $("#write1").append(`<p>High Risk Lung Cancer Job: ${LC_job}</p>`);
#                     $("#write1").append(`<p>Asbestos Exposure: ${AB_exp}</p>`);
#                     $.get("https://bioed.bu.edu/cgi-bin/students_22/resh10/tables.py",
#                       {selector:"pcga",sampletype:sampletype,cohorttype:cohorttype,sex:sex,status:status,LC_history:LC_history,LC_job:LC_job,AB_exp:AB_exp},
#                       function(data){create_table(data);},"json");
#             });
#             function create_table(data){
#                 $("#result_table").empty();
#                 let table_body_contents = "";
#                 if (data ==""){
#                     $("#result_table").append(`<p style="color:red">There are no matching data in the database</p>`)
#                     return false;}
#                 if (data!=""){
#                     $("#result_table").append(`<h3 style="color:#008080">Here is the PCGA Annotation table for the given filters:</h3><br></br>`)
#                     for (let row = 0; row<data.length; row++) {
#                         let Sample_id = data[row][0];
#                         let SampleType = data[row][1];
#                         let Cohort = data[row][2];
#                         let Batch = data[row][3];
#                         let Total_PE_Reads = data[row][4];
#                         let Percent_Uniquely_aligned = data[row][5];
#                         let Median_TIN = data[row][6];
#                         let Location = data[row][10];
#                         let Dysplasia_Grade = data[row][12];
#                         let Histology_Code = data[row][13];
#                         let Molecular_subtype = data[row][17];
#                         let Progression_Status = data[row][19];
#                         let Age_at_Baseline = data[row][20];
#                         let Race = data[row][21];
#                         let Sex = data[row][22];
#                         let Smoking_Status = data[row][23];
#                         let LC_History = data[row][24];
#                         let Asbestos_Exp = data[row][26];
#                         let HighRisk_LC_Job = data[row][27];
#                         let COPD_Status = data[row][28];
#                         let TCGA_Subtype = data[row][32];
#                         let Module_1 = data[row][34];
#                         let Module_2 = data[row][38];
#                         let Module_3 = data[row][37];
#                         let Module_4 = data[row][41];
#                         let Module_5 = data[row][35];
#                         let Module_6 = data[row][33];
#                         let Module_7 = data[row][40];
#                         let Module_8 = data[row][36];
#                         let Module_9 = data[row][39];
#                         let AnalytRNAIsolationNAmes = data[row][42];
#
#                         table_body_contents += `<tr><td>${Sample_id}</td><td>${SampleType}</td><td>${Cohort}</td><td>${Batch}</td><td>${Total_PE_Reads}</td><td>${Percent_Uniquely_aligned}</td><td>${Median_TIN}</td><td>${Location}</td><td>${Dysplasia_Grade}</td><td>${Histology_Code}</td><td>${Molecular_subtype}</td><td>${Progression_Status}</td><td>${Age_at_Baseline}</td><td>${Race}</td><td>${Sex}</td><td>${Smoking_Status}</td><td>${LC_History}</td><td>${Asbestos_Exp}</td></tr>`;
#                     }
#                 let table_template = `<table><thead><tr><th>Sample_id</th><th>SampleType</th><th>Cohort</th><th>Batch</th><th>Total_PE_Reads</th><th>Percent_Uniquely_aligned</th><th>Median_TIN</th><th>Location</th><th>Dysplasia_Grade</th><th>Histology_Code</th><th>Molecular_subtype</th><th>Progression_Status</th><th>Age_at_Baseline</th><th>Race</th><th>Sex</th><th>Smoking_Status</th><th>LC_History</th><th>Asbestos_Exp</th></tr></thead><tbody>${table_body_contents}</tbody></table>`;
#                 $("#result_table").append(table_template)
#                 }
#             }
#
#             });
#         </script>
#     </body>
# </html>
# Out:
# <html>
#     <head>
#         <script type="text/javascript"></script>
#         <meta charset="utf-8" /></script>
#         <script src="https://www.gstatic.com/charts/loader.js"></script>
#         <script src="https://code.jquery.com/jquery-3.4.1.js"></script>
#         <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
#         <h1>Association of Lung Cancer Imaging With Genomic and Clinical Data</h1>
#         <script type="text/javascript"></script>
#         <style>
#             h1 {
#                 padding: 60px;
#                 text-align: center;
#                 background: #1ABC9C;
#                 color: white;
#                 font-size: 30px;
#                 }
#             .navbar {
#                 overflow: hidden;
#                 background-color: #008080;
#                 font-family: Arial, Helvetica, sans-serif;
#                 }
#             .navbar a {
# ...
