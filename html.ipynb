# %%
# %%html
# <html>
#    <head>
#       <style>
#          .tableFixHead          { overflow: auto; height: 100px; }
#          .tableFixHead thead th { position: sticky; top: 0; z-index: 1; }
#          table  { border-collapse: collapse; width: 100%; }
#          th, td { padding: 8px 16px; }
#          th     { background:#eee; }
#       </style>
#    </head>
#    <body>
#       <h2>Association of Lung Cancer Imaging With Genomic and Clinical Data</h2>
#       <p>A database that connects these feature vectors to various forms of genomic and clinical data and visualize those associations in premalignant/malignant lesions.</p>
#       <div class="row">
#          <div class="table-responsive col-md-6">
#             <table id="tblOne" style="width:50%; float:left; text-align:center;">
#                <caption>Sample Typet</caption>
#                 <th scope="col">Sample Type</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Biopsy</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Brush</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tbltwo" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Cohort</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Discovery</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Validation</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblthree" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Dysplasia Grade</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Normal</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>ModD</td>
#                   </tr>
#                   <td><input type="checkbox"></td>
#                   <td>Hyperplasia</td>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Metaplasia</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>MildD</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>UNK</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>SevD</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblfour" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Molecular Subtype</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Secretory</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Proliferative</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Normal</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Inflammatory</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblfive" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Genomic Smoking Status</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Current</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Former</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblsix" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Previous Lung Cancer History</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Yes</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>No</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblseven" style="width:50%; float:left; text-align:center;">
#                <th scope="col">HighRisk Lung Cancer Job</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Yes</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>No</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tbleight" style="width:50%; float:left; text-align:center;">
#                <th scope="col">TCGA Subtype</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Secretory</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Basal</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Primitive</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Classical</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblnine" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Chronic obstructive pulmonary disease(COPD)History </th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Yes</td>
#                      <td>
#                         <select name="COPD-stage" id="COPD-stage">
#                            <option value="">--Please choose the GOLD stage--</option>
#                            <option value="1">1</option>
#                            <option value="2">2</option>
#                            <option value="3">3</option>
#                         </select>
#                      </td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>No</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblnine" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Asbestos Exposure</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Yes</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>No</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="tableFixHead">
#             <table id="tblten" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Location</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LLL Antero Medial Basal Segment (AMBS)</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Lingula Orifice or opening</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Main Carina, Carina NOS</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RLL Superior Basal Segment (SBS)</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RLL Medial Basal Segment (MBS)</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RLL Anterior Basal Seg (ABS)</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RLL ABS Carina between RB8 and RB9</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Main Bronchus, incl Secondary Carina right</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Middle Lobe Orifice or opening</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LUL  SLS Carina between LB4 and LB5</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Left Main Bronchus, incl Secondary Carina left</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RUL Carina between RB2 and RB3</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Upper Lobe Orifice or opening</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LUL  ANTS Carina between LB3A and B</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Left Upper Division Bronchus</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LUL APS Carina between LB1+2 and LB3</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RUL Carina between RB1 and RB2</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Upper Lobe Bronchus</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Upper Lobe Stump</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LUL Apical-Posterior Segment (APS)</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LUL APS Carina between LB1 and LB2</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LLL  Superior Segment (SS)</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RUL Apical Segment (AS)</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Middle Lobe Bronchus</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LLL  SS Carina between LB6A and B</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RML LS Carina between RB4 and RB5</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Left Lower Lobe Orifice or opening</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Lower Lobe Stump</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Left Lower Lobe Stump</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Left Upper Lobe Bronchus</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Lower Lobe Orifice</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Lingular Division Bronchus</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>lingular bronchus</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tbleleven" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Age at Baseline</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> 50.0-55.0</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>55.0-60.0</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>60.0-65.0</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>65.0-70.0</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>70.0-75.0</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>75.0-80.0</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#       </div>
#    </body>
# </html>
# Out:
# <html>
#    <head>
#       <style>
#          .tableFixHead          { overflow: auto; height: 100px; }
#          .tableFixHead thead th { position: sticky; top: 0; z-index: 1; }
#          table  { border-collapse: collapse; width: 100%; }
#          th, td { padding: 8px 16px; }
#          th     { background:#eee; }
#       </style>
#    </head>
#    <body>
#       <h2>Association of Lung Cancer Imaging With Genomic and Clinical Data</h2>
#       <p>A database that connects these feature vectors to various forms of genomic and clinical data and visualize those associations in premalignant/malignant lesions.</p>
#       <div class="row">
#          <div class="table-responsive col-md-6">
#             <table id="tblOne" style="width:50%; float:left; text-align:center;">
#                <caption>Sample Typet</caption>
#                 <th scope="col">Sample Type</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Biopsy</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Brush</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tbltwo" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Cohort</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Discovery</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Validation</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblthree" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Dysplasia Grade</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Normal</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>ModD</td>
#                   </tr>
#                   <td><input type="checkbox"></td>
#                   <td>Hyperplasia</td>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Metaplasia</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>MildD</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>UNK</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>SevD</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblfour" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Molecular Subtype</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Secretory</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Proliferative</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Normal</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Inflammatory</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblfive" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Genomic Smoking Status</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Current</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Former</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblsix" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Previous Lung Cancer History</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Yes</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>No</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblseven" style="width:50%; float:left; text-align:center;">
#                <th scope="col">HighRisk Lung Cancer Job</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Yes</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>No</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tbleight" style="width:50%; float:left; text-align:center;">
#                <th scope="col">TCGA Subtype</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Secretory</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Basal</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Primitive</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Classical</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblnine" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Chronic obstructive pulmonary disease(COPD)History </th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Yes</td>
#                      <td>
#                         <select name="COPD-stage" id="COPD-stage">
#                            <option value="">--Please choose the GOLD stage--</option>
#                            <option value="1">1</option>
#                            <option value="2">2</option>
#                            <option value="3">3</option>
#                         </select>
#                      </td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>No</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblnine" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Asbestos Exposure</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Yes</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>No</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="tableFixHead">
#             <table id="tblten" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Location</th>
#                <tbody>
#                   <tr>

# %%
# %%html
# <html>
#    <head>
#       <script src="Scripts/ScrollableTablePlugin_1.0_min.js" type="text/javascript"></script>
#       <script type="text/javascript"></script>
#       <meta charset="utf-8" /></script>
#       <script src="https://code.jquery.com/jquery-3.4.1.js"></script>
#    </head>
#    <body>
#       <h2>Association of Lung Cancer Imaging With Genomic and Clinical Data</h2>
#       <p>A database that connects these feature vectors to various forms of genomic and clinical data and visualize those associations in premalignant/malignant lesions.</p>
#         <style>
#                   table, th, td {
#                     padding: 15px;
#                   border: 1px solid black;
#                   border-collapse: collapse;
#                   }
#                   tr:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                   th:nth-child(even),td:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                </style>
#       <div class="row">
#          <div class="table-responsive col-md-6">
#             <table id="tblOne" style="width:30%; float:left; text-align:center;">
#                <th scope="col">Sample Type</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Biopsy</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Brush</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#         <br></br>
#          <div class="table-responsive col-md-6">
#             <table id="tbltwo" style="width:30%; float:left; text-align:center;">
#                <th scope="col">Cohort</th>
#                <style>
#                   table, th, td {
#                       padding: 15px;
#                   border: 1px solid black;
#                   border-collapse: collapse;
#                   }
#                   tr:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                   th:nth-child(even),td:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                </style>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Discovery</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Validation</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#         <br></br>
#          <div class="table-responsive col-md-6">
#             <table id="tblthree" style="width:30%; float:left; text-align:center;">
#                <th scope="col">Dysplasia Grade</th>
#                <style>
#                   table, th, td {
#                       padding: 15px;
#                   border: 1px solid black;
#                   border-collapse: collapse;
#                   }
#                   tr:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                   th:nth-child(even),td:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                </style>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Normal</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>ModD</td>
#                   </tr>
#                   <td><input type="checkbox"></td>
#                   <td>Hyperplasia</td>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Metaplasia</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>MildD</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>UNK</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>SevD</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#         <br></br>
#          <div class="table-responsive col-md-6">
#             <table id="tblfour" style="width:30%; float:left; text-align:center;">
#                <th scope="col">Molecular Subtype</th>
#                <style>
#                   table, th, td {
#                       padding: 15px;
#                   border: 1px solid black;
#                   border-collapse: collapse;
#                   }
#                   tr:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                   th:nth-child(even),td:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                </style>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Secretory</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Proliferative</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Normal</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Inflammatory</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblfive" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Genomic Smoking Status</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Current</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Former</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblsix" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Previous Lung Cancer History</th>
#                <style>
#                   table, th, td {
#                       padding: 15px;
#                   border: 1px solid black;
#                   border-collapse: collapse;
#                   }
#                   tr:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                   th:nth-child(even),td:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                </style>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Yes</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>No</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblseven" style="width:50%; float:left; text-align:center;">
#                <th scope="col">HighRisk Lung Cancer Job</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Yes</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>No</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tbleight" style="width:50%; float:left; text-align:center;">
#                <th scope="col">TCGA Subtype</th>
#                <style>
#                   table, th, td {
#                       padding: 15px;
#                   border: 1px solid black;
#                   border-collapse: collapse;
#                   }
#                   tr:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                   th:nth-child(even),td:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                </style>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Secretory</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Basal</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Primitive</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Classical</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblnine" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Chronic obstructive pulmonary disease(COPD)History </th>
#                <style>
#                   table, th, td {
#                       padding: 15px;
#                   border: 1px solid black;
#                   border-collapse: collapse;
#                   }
#                   tr:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                   th:nth-child(even),td:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                </style>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Yes</td>
#                      <td>
#                         <select name="COPD-stage" id="COPD-stage">
#                            <option value="">--Please choose the GOLD stage--</option>
#                            <option value="1">1</option>
#                            <option value="2">2</option>
#                            <option value="3">3</option>
#                         </select>
#                      </td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>No</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblnine" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Asbestos Exposure</th>
#                <style>
#                   tblnine, th, td {
#                   border: 1px solid black;
#                   border-collapse: collapse;
#                   }
#                   tr:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                   th:nth-child(even),td:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                </style>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Yes</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>No</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblten" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Location</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LLL Antero Medial Basal Segment (AMBS)</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Lingula Orifice or opening</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Main Carina, Carina NOS</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RLL Superior Basal Segment (SBS)</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RLL Medial Basal Segment (MBS)</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RLL Anterior Basal Seg (ABS)</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RLL ABS Carina between RB8 and RB9</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Main Bronchus, incl Secondary Carina right</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Middle Lobe Orifice or opening</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LUL  SLS Carina between LB4 and LB5</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Left Main Bronchus, incl Secondary Carina left</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RUL Carina between RB2 and RB3</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Upper Lobe Orifice or opening</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LUL  ANTS Carina between LB3A and B</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Left Upper Division Bronchus</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LUL APS Carina between LB1+2 and LB3</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RUL Carina between RB1 and RB2</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Upper Lobe Bronchus</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Upper Lobe Stump</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LUL Apical-Posterior Segment (APS)</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LUL APS Carina between LB1 and LB2</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LLL  Superior Segment (SS)</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RUL Apical Segment (AS)</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Middle Lobe Bronchus</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>LLL  SS Carina between LB6A and B</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>RML LS Carina between RB4 and RB5</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Left Lower Lobe Orifice or opening</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Lower Lobe Stump</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Left Lower Lobe Stump</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Left Upper Lobe Bronchus</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Right Lower Lobe Orifice</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Lingular Division Bronchus</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>lingular bronchus</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tbleleven" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Age at Baseline</th>
#                <style>
#                   table, th, td {
#                   border: 1px solid black;
#                   border-collapse: collapse;
#                   }
#                   tr:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                   th:nth-child(even),td:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                </style>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> 50.0-55.0</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>55.0-60.0</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>60.0-65.0</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>65.0-70.0</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>70.0-75.0</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>75.0-80.0</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#       </div>
#     <script>
#         $(document).ready(function(){
#                 $(":button").click(function(){
#                     getLocation();
#                 });
#             });
#         function getLocation(){
#                 />>>>>>>>> AJAX .get() request for location options here <<<<<<<<<<<//
#                 $.get("https://bioed.bu.edu/cgi-bin/gbenson/getInfoFromPathwaysDbForAjax3.py",
#                       {selector: "location"},
#                       function(data){
#                           format_location_options(data);
#                       },
#                       "json"
#                 );
#                 //>>>>>>>>>>>>>>>>>>>>>>>>>>>>><<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#             }
#         function format_location_options(data){
#                 var location_options = "";
#                 for (let row = 0; row<data.length; row++) {
#                   location = data[row];
#                   location_options += `<tr><td><input type="checkbox"></td><td>${location}</td></tr>`;
#                 }
#                 let location_template = `<th scope="col">Location</th><tbody>${location_options}</tbody>`
#                 $("#tblten").append(location_template);
#             }
#     </script>
#    </body>
# </html>
# Out:
# <html>
#    <head>
#       <script src="Scripts/ScrollableTablePlugin_1.0_min.js" type="text/javascript"></script>
#       <script type="text/javascript"></script>
#       <meta charset="utf-8" /></script>
#       <script src="https://code.jquery.com/jquery-3.4.1.js"></script>
#    </head>
#    <body>
#       <h2>Association of Lung Cancer Imaging With Genomic and Clinical Data</h2>
#       <p>A database that connects these feature vectors to various forms of genomic and clinical data and visualize those associations in premalignant/malignant lesions.</p>
#         <style>
#                   table, th, td {
#                     padding: 15px;
#                   border: 1px solid black;
#                   border-collapse: collapse;
#                   }
#                   tr:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                   th:nth-child(even),td:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                </style>
#       <div class="row">
#          <div class="table-responsive col-md-6">
#             <table id="tblOne" style="width:30%; float:left; text-align:center;">
#                <th scope="col">Sample Type</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Biopsy</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Brush</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#         <br></br>
#          <div class="table-responsive col-md-6">
#             <table id="tbltwo" style="width:30%; float:left; text-align:center;">
#                <th scope="col">Cohort</th>
#                <style>
#                   table, th, td {
#                       padding: 15px;
#                   border: 1px solid black;
#                   border-collapse: collapse;
#                   }
#                   tr:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                   th:nth-child(even),td:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                </style>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Discovery</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Validation</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#         <br></br>
#          <div class="table-responsive col-md-6">
#             <table id="tblthree" style="width:30%; float:left; text-align:center;">
#                <th scope="col">Dysplasia Grade</th>
#                <style>
#                   table, th, td {
#                       padding: 15px;
#                   border: 1px solid black;
#                   border-collapse: collapse;
#                   }
#                   tr:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                   th:nth-child(even),td:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                </style>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Normal</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>ModD</td>
#                   </tr>
#                   <td><input type="checkbox"></td>
#                   <td>Hyperplasia</td>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Metaplasia</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>MildD</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>UNK</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>SevD</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#         <br></br>
#          <div class="table-responsive col-md-6">
#             <table id="tblfour" style="width:30%; float:left; text-align:center;">
#                <th scope="col">Molecular Subtype</th>
#                <style>
#                   table, th, td {
#                       padding: 15px;
#                   border: 1px solid black;
#                   border-collapse: collapse;
#                   }
#                   tr:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                   th:nth-child(even),td:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                </style>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Secretory</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Proliferative</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Normal</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Inflammatory</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblfive" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Genomic Smoking Status</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Current</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>Former</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblsix" style="width:50%; float:left; text-align:center;">
#                <th scope="col">Previous Lung Cancer History</th>
#                <style>
#                   table, th, td {
#                       padding: 15px;
#                   border: 1px solid black;
#                   border-collapse: collapse;
#                   }
#                   tr:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                   th:nth-child(even),td:nth-child(even) {
#                   background-color: rgba(150, 212, 212, 0.4);
#                   }
#                </style>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Yes</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>No</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tblseven" style="width:50%; float:left; text-align:center;">
#                <th scope="col">HighRisk Lung Cancer Job</th>
#                <tbody>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td> Yes</td>
#                   </tr>
#                   <tr>
#                      <td><input type="checkbox"></td>
#                      <td>No</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="table-responsive col-md-6">
#             <table id="tbleight" style="width:50%; float:left; text-align:center;">
#                <th scope="col">TCGA Subtype</th>
#                <s

# %%
# %%html
# <html>
#     <head>
#         <script src="Scripts/ScrollableTablePlugin_1.0_min.js" type="text/javascript"></script>
#         <script type="text/javascript"></script>
#         <meta charset="utf-8" /></script>
#         <script src="https://code.jquery.com/jquery-3.4.1.js"></script>
#         <style>
#             .main {
#                 width: 1800px; //depending on how wide you want the table window
#                 min-height: 615px;  //same as width
#                 margin: 0 auto; //to center the content on your screen
#                 display: flex;
#                 justify-content: space-between;}
#         </style>
#     </head>
#     <body>
#         <h2>Association of Lung Cancer Imaging With Genomic and Clinical Data</h2>
#         <p>A database that connects these feature vectors to various forms of genomic and clinical data and visualize those associations in premalignant/malignant lesions.</p>
#     <div class="table-responsive col-md-6">
#          <table id="MolecularSubtype" style="width:40%; float:left; text-align:center;">
#                 <caption>Molecular Subtype</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Normal" class="MolecularSubtype" type="checkbox" value="Normal"/></td>
#                         <td>Normal</td>
#                     </tr>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Secretory" class="MolecularSubtype" type="checkbox" value="Secretory"/></td>
#                         <td>Secretory</td>
#                     </tr>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Proliferative" class="MolecularSubtype" type="checkbox" value="Proliferative"/></td>
#                         <td>Proliferative</td>
#                     </tr>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Inflammatory" class="MolecularSubtype" type="checkbox" value="Inflammatory"/></td>
#                         <td>Inflammatory</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     <div class="table-responsive col-md-6">
#          <table id="DysplasiaGrade" style="width:40%; text-align:center;">
#                 <caption>Dysplasia Grade</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="Normal" class="DysplasiaGrade" type="checkbox" value="Normal"/></td>
#                         <td>Normal</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="MildD" class="DysplasiaGrade" type="checkbox" value="MildD"/></td>
#                         <td>MildD</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="ModD" class="DysplasiaGrade" type="checkbox" value="ModD"/></td>
#                         <td>ModD</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="SevD" class="DysplasiaGrade" type="checkbox" value="SevD"/></td>
#                         <td>SevD</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="Metaplasia" class="DysplasiaGrade" type="checkbox" value="Metaplasia"/></td>
#                         <td>Metaplasia</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="Hyperplasia" class="DysplasiaGrade" type="checkbox" value="Hyperplasia"/></td>
#                         <td>Hyperplasia</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="UNK" class="DysplasiaGrade" type="checkbox" value="UNK"/></td>
#                         <td>UNK</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     <div class="table-responsive col-md-6">
#          <table id="TCGASubtype" style="width:50%; text-align:center;">
#                 <caption>TCGA Subtype</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="TCGASubtype[]" id="Basal" class="TCGASubtype" type="checkbox" value="Basal"/></td>
#                         <td>Basal</td>
#                     </tr>
#                     <tr>
#                         <td><input name="TCGASubtype[]" id="Classical" class="TCGASubtype" type="checkbox" value="Classical"/></td>
#                         <td>Classical</td>
#                     </tr>
#                     <tr>
#                         <td><input name="TCGASubtype[]" id="Primitive" class="TCGASubtype" type="checkbox" value="Primitive"/></td>
#                         <td>Primitive</td>
#                     </tr>
#                     <tr>
#                         <td><input name="TCGASubtype[]" id="Secretory" class="TCGASubtype" type="checkbox" value="Secretory"/></td>
#                         <td>Secretory</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     <div class="table-responsive col-md-6">
#          <table id="AgeatBaseline" style="width:50%; float:left; text-align:center;">
#                 <caption>Age at Baseline</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="AgeatBaseline[]" id="50.0-60.0" class="AgeatBaseline" type="checkbox" value="50"/></td>
#                         <td>50.0-60.0</td>
#                     </tr>
#                     <tr>
#                         <td><input name="AgeatBaseline[]" id="60.0-70.0" class="AgeatBaseline" type="checkbox" value="60"/></td>
#                         <td>60.0-70.0</td>
#                     </tr>
#                     <tr>
#                         <td><input name="AgeatBaseline[]" id="70.0-80.0" class="AgeatBaseline" type="checkbox" value="70"/></td>
#                         <td>70.0-80.0</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     <div class="table-responsive col-md-6">
#          <table id="Location" style="width:50%; float:left; text-align:center;">
#                 <caption>Location</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="Location[]" id="Basal" class="Location" type="checkbox" value="Basal"/></td>
#                         <td>Basal</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     <div><input type="button" id="save_value" name="save_value" value="Save" /></div>
#     <div id = "write"></div>
#     <script>
#         $(document).ready(function(){
#             $("#write").append(`<h1>MolecularSubtype</h1>`);
#             $('#save_value').click(function() {
#                 $("#write").append(`<h1>MolecularSubtype</h1>`);
#                 var MolecularSubtype = []
#                 var DysplasiaGrade = []
#                 var TCGASubtype = []
#                 var AgeatBaseline = []
#                 var Location = []
#                 var i = 0
#                 $('.MolecularSubtype:checked').each(function(i) {
#                     MolecularSubtype[i++] = $(this).val();});
#                 $('.DysplasiaGrade:checked').each(function(i) {
#                     DysplasiaGrade[i++] = $(this).val();});
#                 $('.TCGASubtype:checked').each(function(i) {
#                     TCGASubtype[i++] = $(this).val();});
#                 $('.AgeatBaseline:checked').each(function(i) {
#                     AgeatBaseline[i++] = $(this).val();});
#                 $('.Location:checked').each(function(i) {
#                     Location[i++] = $(this).val();});
#                 $("#write").append(`<h1>MolecularSubtype: ${MolecularSubtype}</h1>`)
#                 $("#write").append(`<h1>Dysplasia Grade: ${DysplasiaGrade}</h1>`)
#                 $("#write").append(`<h1>TCGA Subtype: ${TCGASubtype}</h1>`)
#                 $("#write").append(`<h1>Age at Baseline: ${AgeatBaseline}</h1>`)
#                 $("#write").append(`<h1>Location: ${Location}</h1>`)
#             ;});});
#     </script>
#     </body>
# </html>
# Out:
# <html>
#     <head>
#         <script src="Scripts/ScrollableTablePlugin_1.0_min.js" type="text/javascript"></script>
#         <script type="text/javascript"></script>
#         <meta charset="utf-8" /></script>
#         <script src="https://code.jquery.com/jquery-3.4.1.js"></script>
#         <style>
#             .main {
#                 width: 1800px; //depending on how wide you want the table window
#                 min-height: 615px;  //same as width
#                 margin: 0 auto; //to center the content on your screen
#                 display: flex;
#                 justify-content: space-between;}
#         </style>
#     </head>
#     <body>
#         <h2>Association of Lung Cancer Imaging With Genomic and Clinical Data</h2>
#         <p>A database that connects these feature vectors to various forms of genomic and clinical data and visualize those associations in premalignant/malignant lesions.</p>
#     <div class="table-responsive col-md-6">
#          <table id="MolecularSubtype" style="width:40%; float:left; text-align:center;">
#                 <caption>Molecular Subtype</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Normal" class="MolecularSubtype" type="checkbox" value="Normal"/></td>
#                         <td>Normal</td>
#                     </tr>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Secretory" class="MolecularSubtype" type="checkbox" value="Secretory"/></td>
#                         <td>Secretory</td>
#                     </tr>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Proliferative" class="MolecularSubtype" type="checkbox" value="Proliferative"/></td>
#                         <td>Proliferative</td>
#                     </tr>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Inflammatory" class="MolecularSubtype" type="checkbox" value="Inflammatory"/></td>
#                         <td>Inflammatory</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     <div class="table-responsive col-md-6">
#          <table id="DysplasiaGrade" style="width:40%; text-align:center;">
#                 <caption>Dysplasia Grade</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="Normal" class="DysplasiaGrade" type="checkbox" value="Normal"/></td>
#                         <td>Normal</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="MildD" class="DysplasiaGrade" type="checkbox" value="MildD"/></td>
#                         <td>MildD</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="ModD" class="DysplasiaGrade" type="checkbox" value="ModD"/></td>
#                         <td>ModD</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="SevD" class="DysplasiaGrade" type="checkbox" value="SevD"/></td>
#                         <td>SevD</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="Metaplasia" class="DysplasiaGrade" type="checkbox" value="Metaplasia"/></td>
#                         <td>Metaplasia</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="Hyperplasia" class="DysplasiaGrade" type="checkbox" value="Hyperplasia"/></td>
#                         <td>Hyperplasia</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="UNK" class="DysplasiaGrade" type="checkbox" value="UNK"/></td>
#                         <td>UNK</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     <div class="table-responsive col-md-6">
#          <table id="TCGASubtype" style="width:50%; text-align:center;">
#                 <caption>TCGA Subtype</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="TCGASubtype[]" id="Basal" class="TCGASubtype" type="checkbox" value="Basal"/></td>
#                         <td>Basal</td>
#                     </tr>
#                     <tr>
#                         <td><input name="TCGASubtype[]" id="Classical" class="TCGASubtype" type="checkbox" value="Classical"/></td>
#                         <td>Classical</td>
#                     </tr>
#                     <tr>
#                         <td><input name="TCGASubtype[]" id="Primitive" class="TCGASubtype" type="checkbox" value="Primitive"/></td>
#                         <td>Primitive</td>
#                     </tr>
#                     <tr>
#                         <td><input name="TCGASubtype[]" id="Secretory" class="TCGASubtype" type="checkbox" value="Secretory"/></td>
#                         <td>Secretory</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     <div class="table-responsive col-md-6">
#          <table id="AgeatBaseline" style="width:50%; float:left; text-align:center;">
#                 <caption>Age at Baseline</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="AgeatBaseline[]" id="50.0-60.0" class="AgeatBaseline" type="checkbox" value="50"/></td>
#                         <td>50.0-60.0</td>
#                     </tr>
#                     <tr>
#                         <td><input name="AgeatBaseline[]" id="60.0-70.0" class="AgeatBaseline" type="checkbox" value="60"/></td>
#                         <td>60.0-70.0</td>
#                     </tr>
#                     <tr>
#                         <td><input name="AgeatBaseline[]" id="70.0-80.0" class="AgeatBaseline" type="checkbox" value="70"/></td>
#                         <td>70.0-80.0</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     <div class="table-responsive col-md-6">
#          <table id="Location" style="width:50%; float:left; text-align:center;">
#                 <caption>Location</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="Location[]" id="Basal" class="Location" type="checkbox" value="Basal"/></td>
#                         <td>Basal</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     <div><input type="button" id="save_value" name="save_value" value="Save" /></div>
#     <div id = "write"></div>
#     <script>
#         $(document).ready(function(){
#             $("#write").append(`<h1>MolecularSubtype</h1>`);
#             $('#save_value').click(function() {
#                 $("#write").append(`<h1>MolecularSubtype</h1>`);
#                 var MolecularSubtype = []
#                 var DysplasiaGrade = []
#                 var TCGASubtype = []
#                 var AgeatBaseline = []
#                 var Location = []
#                 var i = 0
#                 $('.MolecularSubtype:checked').each(function(i) {
#                     MolecularSubtype[i++] = $(this).val();});
#                 $('.DysplasiaGrade:checked').each(function(i) {
#                     DysplasiaGrade[i++] = $(this).val();});
#                 $('.TCGASubtype:checked').each(function(i) {
#                     TCGASubtype[i++] = $(this).val();});
#                 $('.AgeatBaseline:checked').each(function(i) {
#                     AgeatBaseline[i++] = $(this).val();});
#                 $('.Location:checked').each(function(i) {
#                     Location[i++] = $(this).val();});
#                 $("#write").append(`<h1>MolecularSubtype: ${MolecularSubtype}</h1>`)
#                 $("#write").append(`<h1>Dysplasia Grade: ${DysplasiaGrade}</h1>`)
#                 $("#write").append(`<h1>TCGA Subtype: ${TCGASubtype}</h1>`)
#                 $("#write").append(`<h1>Age at Baseline: ${AgeatBaseline}</h1>`)
#                 $("#write").append(`<h1>Location: ${Location}</h1>`)

# %%
https://bioed.bu.edu/students_22/resh10/project1.html

# %%
# %%html
# <!DOCTYPE html>
# <html>
#    <head>
#       <meta name="viewport" content="width=device-width, initial-scale=1">
#       <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
#       <h2>Association of Lung Cancer Imaging With Genomic and Clinical Data</h2>
#       <p>A database that connects these feature vectors to various forms of genomic and clinical data and visualize those associations in premalignant/malignant lesions.</p>
#       <script src="Scripts/ScrollableTablePlugin_1.0_min.js" type="text/javascript"></script>
#       <script type="text/javascript"></script>
#       <meta charset="utf-8" />
#       </script>
#       <script src="https://code.jquery.com/jquery-3.4.1.js"></script>
#       <style>
#          .navbar {
#          overflow: hidden;
#          background-color: #008080;
#          font-family: Arial, Helvetica, sans-serif;
#          }
#          .navbar a {
#          float: left;
#          font-size: 16px;
#          color: white;
#          text-align: center;
#          padding: 14px 16px;
#          text-decoration: none;
#          }
#          .dropdown {
#          float: left;
#          overflow: hidden;
#          }
#          .dropdown .dropbtn {
#          cursor: pointer;
#          font-size: 16px;
#          border: none;
#          outline: none;
#          color: white;
#          padding: 14px 16px;
#          background-color: inherit;
#          font-family: inherit;
#          margin: 0;
#          }
#          .navbar a:hover, .dropdown:hover .dropbtn, .dropbtn:focus {
#          background-color: #008B8B;
#          }
#          .show {
#          display: block;
#          }
#         * {box-sizing: border-box;}
#             .row {
#                 margin-left:-5px;
#                 margin-right:-5px;
#                 }
#             .column {
#                 float: left;
#                 width: 40%;
#                 padding: 15px;
#                 }
#             /* Clearfix (clear floats) */
#                 .row::after {
#                 content: "";
#                 clear: both;
#                 display: table;
#                 }
#             table {
#                 border-collapse: collapse;
#                 border-spacing: 0;
#                 width: 80%;
#                 border: 1px solid #ddd;
#                 }
#               th, td {
#                 text-align: left;
#                 padding: 16px;
#                 }
#             tr:nth-child(even) {
#                 background-color: #F2F2F2;
#                 }
#       </style>
#    </head>
#    <body>
#       <div class="navbar">
#          <a href="#home">Home</a>
#          <a href="#help">Help</a>
#       </div>
#       </div>
#       <br><br>
#       Sample Type:
#       <select name="sampletype" id="sampletype">
#          <option value="" selected="selected">Choose the Sample type </option>
#          <option value="Biopsy">Biopsy</option>
#          <option value="Brush">Brush</option>
#       </select>
#       <br><br>
#       Cohort:
#       <select name="cohorttype" id="cohorttype">
#          <option value="" selected="selected">Choose the Cohort type </option>
#          <option value="Discovery">Discovery</option>
#          <option value="Validation">Validation</option>
#       </select>
#       <br><br>
#       Genomic Smoking Status:
#       <select name="status" id="status">
#          <option value="" selected="selected">Choose the Smoking Status type </option>
#          <option value="Current">Current</option>
#          <option value="Former">Former</option>
#       </select>
#       <br><br>
#       Previous Lung Cancer History:
#       <select name="LC_history" id="LC_history">
#          <option value="" selected="selected">Choose the Lung Cancer History type </option>
#          <option value="Yes">Yes</option>
#          <option value="No">No</option>
#       </select>
#       <br><br>
#       High Risk Lung Cancer Job:
#       <select name="LC_job" id="LC_job">
#          <option value="" selected="selected">Choose Lung Cancer Job type </option>
#          <option value="Yes">Yes</option>
#          <option value="No">No</option>
#       </select>
#       <br><br>
#       Asbestos Exposure:
#       <select name="AB_exp" id="AB_exp">
#          <option value="" selected="selected">Choose the Asebestos Exposure type </option>
#          <option value="Yes">Yes</option>
#          <option value="No">No</option>
#       </select>
#       <br><br>
#       <div class="row">
#     <div class="column">
#          <table id="MolecularSubtype">
#                 <caption>Molecular Subtype</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Normal" class="MolecularSubtype" type="checkbox" value="Normal"/></td>
#                         <td>Normal</td>
#                     </tr>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Secretory" class="MolecularSubtype" type="checkbox" value="Secretory"/></td>
#                         <td>Secretory</td>
#                     </tr>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Proliferative" class="MolecularSubtype" type="checkbox" value="Proliferative"/></td>
#                         <td>Proliferative</td>
#                     </tr>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Inflammatory" class="MolecularSubtype" type="checkbox" value="Inflammatory"/></td>
#                         <td>Inflammatory</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     <div class="column">
#          <table id="DysplasiaGrade">
#                 <caption>Dysplasia Grade</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="Normal" class="DysplasiaGrade" type="checkbox" value="Normal"/></td>
#                         <td>Normal</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="MildD" class="DysplasiaGrade" type="checkbox" value="MildD"/></td>
#                         <td>MildD</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="ModD" class="DysplasiaGrade" type="checkbox" value="ModD"/></td>
#                         <td>ModD</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="SevD" class="DysplasiaGrade" type="checkbox" value="SevD"/></td>
#                         <td>SevD</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="Metaplasia" class="DysplasiaGrade" type="checkbox" value="Metaplasia"/></td>
#                         <td>Metaplasia</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="Hyperplasia" class="DysplasiaGrade" type="checkbox" value="Hyperplasia"/></td>
#                         <td>Hyperplasia</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="UNK" class="DysplasiaGrade" type="checkbox" value="UNK"/></td>
#                         <td>UNK</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     </div>
#     <div class="row">
#     <div class="column">
#          <table id="TCGASubtype">
#                 <caption>TCGA Subtype</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="TCGASubtype[]" id="Basal" class="TCGASubtype" type="checkbox" value="Basal"/></td>
#                         <td>Basal</td>
#                     </tr>
#                     <tr>
#                         <td><input name="TCGASubtype[]" id="Classical" class="TCGASubtype" type="checkbox" value="Classical"/></td>
#                         <td>Classical</td>
#                     </tr>
#                     <tr>
#                         <td><input name="TCGASubtype[]" id="Primitive" class="TCGASubtype" type="checkbox" value="Primitive"/></td>
#                         <td>Primitive</td>
#                     </tr>
#                     <tr>
#                         <td><input name="TCGASubtype[]" id="Secretory" class="TCGASubtype" type="checkbox" value="Secretory"/></td>
#                         <td>Secretory</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     <div class="column">
#          <table id="AgeatBaseline">
#                 <caption>Age at Baseline</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="AgeatBaseline[]" id="50.0-60.0" class="AgeatBaseline" type="checkbox" value="50"/></td>
#                         <td>50.0-60.0</td>
#                     </tr>
#                     <tr>
#                         <td><input name="AgeatBaseline[]" id="60.0-70.0" class="AgeatBaseline" type="checkbox" value="60"/></td>
#                         <td>60.0-70.0</td>
#                     </tr>
#                     <tr>
#                         <td><input name="AgeatBaseline[]" id="70.0-80.0" class="AgeatBaseline" type="checkbox" value="70"/></td>
#                         <td>70.0-80.0</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     </div>
#     <div class="row">
#     <div class="column">
#          <table id="Location">
#                 <caption>Location</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="Location[]" id="Basal" class="Location" type="checkbox" value="Basal"/></td>
#                         <td>Basal</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     </div>
#     <div><input type="button" id="save_value" name="save_value" value="Submit" /></div>
#     <div id = "write"></div>
#     <script>
#         $(document).ready(function(){
#             $("#write").append(`<h1>MolecularSubtype</h1>`);
#             $('#save_value').click(function() {
#                 $("#write").append(`<h1>MolecularSubtype</h1>`);
#                 var MolecularSubtype = []
#                 var DysplasiaGrade = []
#                 var TCGASubtype = []
#                 var AgeatBaseline = []
#                 var Location = []
#                 var i = 0
#                 $('.MolecularSubtype:checked').each(function(i) {
#                     MolecularSubtype[i++] = $(this).val();});
#                 $('.DysplasiaGrade:checked').each(function(i) {
#                     DysplasiaGrade[i++] = $(this).val();});
#                 $('.TCGASubtype:checked').each(function(i) {
#                     TCGASubtype[i++] = $(this).val();});
#                 $('.AgeatBaseline:checked').each(function(i) {
#                     AgeatBaseline[i++] = $(this).val();});
#                 $('.Location:checked').each(function(i) {
#                     Location[i++] = $(this).val();});
#                 $("#write").append(`<h1>MolecularSubtype: ${MolecularSubtype}</h1>`)
#                 $("#write").append(`<h1>Dysplasia Grade: ${DysplasiaGrade}</h1>`)
#                 $("#write").append(`<h1>TCGA Subtype: ${TCGASubtype}</h1>`)
#                 $("#write").append(`<h1>Age at Baseline: ${AgeatBaseline}</h1>`)
#                 $("#write").append(`<h1>Location: ${Location}</h1>`)
#             ;});});
#       </script>
#    </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html>
#    <head>
#       <meta name="viewport" content="width=device-width, initial-scale=1">
#       <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
#       <h2>Association of Lung Cancer Imaging With Genomic and Clinical Data</h2>
#       <p>A database that connects these feature vectors to various forms of genomic and clinical data and visualize those associations in premalignant/malignant lesions.</p>
#       <script src="Scripts/ScrollableTablePlugin_1.0_min.js" type="text/javascript"></script>
#       <script type="text/javascript"></script>
#       <meta charset="utf-8" />
#       </script>
#       <script src="https://code.jquery.com/jquery-3.4.1.js"></script>
#       <style>
#          .navbar {
#          overflow: hidden;
#          background-color: #008080;
#          font-family: Arial, Helvetica, sans-serif;
#          }
#          .navbar a {
#          float: left;
#          font-size: 16px;
#          color: white;
#          text-align: center;
#          padding: 14px 16px;
#          text-decoration: none;
#          }
#          .dropdown {
#          float: left;
#          overflow: hidden;
#          }
#          .dropdown .dropbtn {
#          cursor: pointer;
#          font-size: 16px;
#          border: none;
#          outline: none;
#          color: white;
#          padding: 14px 16px;
#          background-color: inherit;
#          font-family: inherit;
#          margin: 0;
#          }
#          .navbar a:hover, .dropdown:hover .dropbtn, .dropbtn:focus {
#          background-color: #008B8B;
#          }
#          .show {
#          display: block;
#          }
#         * {box-sizing: border-box;}
#             .row {
#                 margin-left:-5px;
#                 margin-right:-5px;
#                 }
#             .column {
#                 float: left;
#                 width: 40%;
#                 padding: 15px;
#                 }
#             /* Clearfix (clear floats) */
#                 .row::after {
#                 content: "";
#                 clear: both;
#                 display: table;
#                 }
#             table {
#                 border-collapse: collapse;
#                 border-spacing: 0;
#                 width: 80%;
#                 border: 1px solid #ddd;
#                 }
#               th, td {
#                 text-align: left;
#                 padding: 16px;
#                 }
#             tr:nth-child(even) {
#                 background-color: #F2F2F2;
#                 }
#       </style>
#    </head>
#    <body>
#       <div class="navbar">
#          <a href="#home">Home</a>
#          <a href="#help">Help</a>
#       </div>
#       </div>
#       <br><br>
#       Sample Type:
#       <select name="sampletype" id="sampletype">
#          <option value="" selected="selected">Choose the Sample type </option>
#          <option value="Biopsy">Biopsy</option>
#          <option value="Brush">Brush</option>
#       </select>
#       <br><br>
#       Cohort:
#       <select name="cohorttype" id="cohorttype">
#          <option value="" selected="selected">Choose the Cohort type </option>
#          <option value="Discovery">Discovery</option>
#          <option value="Validation">Validation</option>
#       </select>
#       <br><br>
#       Genomic Smoking Status:
#       <select name="status" id="status">
#          <option value="" selected="selected">Choose the Smoking Status type </option>
#          <option value="Current">Current</option>
#          <option value="Former">Former</option>
#       </select>
#       <br><br>
#       Previous Lung Cancer History:
#       <select name="LC_history" id="LC_history">
#          <option value="" selected="selected">Choose the Lung Cancer History type </option>
#          <option value="Yes">Yes</option>
#          <option value="No">No</option>
#       </select>
#       <br><br>
#       High Risk Lung Cancer Job:
#       <select name="LC_job" id="LC_job">
#          <option value="" selected="selected">Choose Lung Cancer Job type </option>
#          <option value="Yes">Yes</option>
#          <option value="No">No</option>
#       </select>
#       <br><br>
#       Asbestos Exposure:
#       <select name="AB_exp" id="AB_exp">
#          <option value="" selected="selected">Choose the Asebestos Exposure type </option>
#          <option value="Yes">Yes</option>
#          <option value="No">No</option>
#       </select>
#       <br><br>
#       <div class="row">
#     <div class="column">
#          <table id="MolecularSubtype">
#                 <caption>Molecular Subtype</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Normal" class="MolecularSubtype" type="checkbox" value="Normal"/></td>
#                         <td>Normal</td>
#                     </tr>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Secretory" class="MolecularSubtype" type="checkbox" value="Secretory"/></td>
#                         <td>Secretory</td>
#                     </tr>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Proliferative" class="MolecularSubtype" type="checkbox" value="Proliferative"/></td>
#                         <td>Proliferative</td>
#                     </tr>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Inflammatory" class="MolecularSubtype" type="checkbox" value="Inflammatory"/></td>
#                         <td>Inflammatory</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     <div class="column">
#          <table id="DysplasiaGrade">
#                 <caption>Dysplasia Grade</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="Normal" class="DysplasiaGrade" type="checkbox" value="Normal"/></td>
#                         <td>Normal</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="MildD" class="DysplasiaGrade" type="checkbox" value="MildD"/></td>
#                         <td>MildD</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="ModD" class="DysplasiaGrade" type="checkbox" value="ModD"/></td>
#                         <td>ModD</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="SevD" class="DysplasiaGrade" type="checkbox" value="SevD"/></td>
#                         <td>SevD</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="Metaplasia" class="DysplasiaGrade" type="checkbox" value="Metaplasia"/></td>
#                         <td>Metaplasia</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="Hyperplasia" class="DysplasiaGrade" type="checkbox" value="Hyperplasia"/></td>
#                         <td>Hyperplasia</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="UNK" class="DysplasiaGrade" type="checkbox" value="UNK"/></td>
#                         <td>UNK</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     </div>
#     <div class="row">
#     <div class="column">
#          <table id="TCGASubtype">
#                 <caption>TCGA Subtype</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="TCGASubtype[]" id="Basal" class="TCGASubtype" type="checkbox" value="Basal"/></td>
#                         <td>Basal</td>
#                     </tr>
#                     <tr>
#                         <td><input name="TCGASubtype[]" id="Classical" class="TCGASubtype" type="checkbox" value="Classical"/></td>
#                         <td>Classical</td>
#                     </tr>
#                     <tr>
#                         <td><input name="TCGASubtype[]" id="Primitive" class="TCGASubtype" type="checkbox" value="Primitive"/></td>

# %%
# %%html
# <html>
#     <head>
#         <script src="Scripts/ScrollableTablePlugin_1.0_min.js" type="text/javascript"></script>
#         <script type="text/javascript"></script>
#         <meta charset="utf-8" /></script>
#         <script src="https://code.jquery.com/jquery-3.4.1.js"></script>
#         <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
#         <h2>Association of Lung Cancer Imaging With Genomic and Clinical Data</h2>
#         <p>A database that connects these feature vectors to various forms of genomic and clinical data and visualize those associations in premalignant/malignant lesions.</p>
#         <script src="Scripts/ScrollableTablePlugin_1.0_min.js" type="text/javascript"></script>
#         <script type="text/javascript"></script>
#         <style>
#             .navbar {
#                 overflow: hidden;
#                 background-color: #008080;
#                 font-family: Arial, Helvetica, sans-serif;
#                 }
#             .navbar a {
#                 float: left;
#                 font-size: 16px;
#                 color: white;
#                 text-align: center;
#                 padding: 14px 16px;
#                 text-decoration: none;
#                 }
#             .dropdown {
#                 float: left;
#                 overflow: hidden;
#                 }
#                 .dropdown .dropbtn {
#                 cursor: pointer;
#                 font-size: 16px;
#                 border: none;
#                 outline: none;
#                 color: white;
#                 padding: 14px 16px;
#                 background-color: inherit;
#                 font-family: inherit;
#                 margin: 0;
#                 }
#                 .navbar a:hover, .dropdown:hover .dropbtn, .dropbtn:focus {
#                 background-color: #008B8B;
#                 }
#                 .show {
#                 display: block;
#                 }
#             * {box-sizing: border-box;}
#             .row {
#                 margin-left:-5px;
#                 margin-right:-5px;
#                 }
#             .column {
#                 float: left;
#                 width: 40%;
#                 padding: 15px;
#                 }
#             /* Clearfix (clear floats) */
#                 .row::after {
#                 content: "";
#                 clear: both;
#                 display: table;
#                 }
#             table {
#                 border-collapse: collapse;
#                 border-spacing: 0;
#                 width: 80%;
#                 border: 1px solid #ddd;
#                 }
#               th, td {
#                 text-align: left;
#                 padding: 16px;
#                 }
#             tr:nth-child(even) {
#                 background-color: #F2F2F2;
#                 }
#         </style>
#     </head>
#     </head>
#     <body>
#         <div class="navbar">
#             <a href="#home">Home</a>
#             <a href="#help">Help</a>
#         </div>
#         <br><br>
#         Sample Type:
#         <select name="sampletype" id="sampletype">
#         <option value="" selected="selected">Choose the Sample type </option>
#         <option value="Biopsy">Biopsy</option>
#         <option value="Brush">Brush</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         Cohort:
#         <select name="cohorttype" id="cohorttype">
#         <option value="" selected="selected">Choose the Cohort type </option>
#         <option value="Discovery">Discovery</option>
#         <option value="Validation">Validation</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         Genomic Smoking Status:
#         <select name="status" id="status">
#         <option value="" selected="selected">Choose the Smoking Status type </option>
#         <option value="Current">Current</option>
#         <option value="Former">Former</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         Previous Lung Cancer History:
#         <select name="LC_history" id="LC_history">
#         <option value="" selected="selected">Choose the Lung Cancer History type </option>
#         <option value="Yes">Yes</option>
#         <option value="No">No</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         High Risk Lung Cancer Job:
#         <select name="LC_job" id="LC_job">
#         <option value="" selected="selected">Choose Lung Cancer Job type </option>
#         <option value="Yes">Yes</option>
#         <option value="No">No</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         Asbestos Exposure:
#         <select name="AB_exp" id="AB_exp">
#         <option value="" selected="selected">Choose the Asebestos Exposure type </option>
#         <option value="Yes">Yes</option>
#         <option value="No">No</option>
#         <option value="">- Both -</option>
#         </select>
#         <input type="button" id="save_valu" name="save_value" value="Submit" />
#         <div id ="writ"></div>
#         <script>
#             $(document).ready(function(){
#                 $("#writ").append(`<h1>in</h1>`);
#                 $('#save_valu').click(function() {
#                     $("#writ").append(`<h1>in2</h1>`);
#                     var sampletype = $("#sampletype").val();
#                     let cohorttype = $("#cohorttype").val();
#                     let status = $("#status").val();
#                     let LC_history = $("#LC_history").val();
#                     let LC_job = $("#LC_job").val();
#                     let AB_exp = $("#AB_exp").val();
#                     $("#writ").append(`<h1>sampletype: ${document.getElementById("sampletype").value}</h1>`);
#                     $("#writ").append(`<h1>cohorttype: ${cohorttype}</h1>`);
#                     $("#writ").append(`<h1>status: ${status}</h1>`);
#                     $("#writ").append(`<h1>LC_history: ${LC_history}</h1>`);
#                     $("#writ").append(`<h1>LC_job: ${LC_job}</h1>`);
#                     $("#writ").append(`<h1>AB_exp: ${AB_exp}</h1>`);
#             ;});});
#         </script>
#     </body>
# </html>
# Out:
# <html>
#     <head>
#         <script src="Scripts/ScrollableTablePlugin_1.0_min.js" type="text/javascript"></script>
#         <script type="text/javascript"></script>
#         <meta charset="utf-8" /></script>
#         <script src="https://code.jquery.com/jquery-3.4.1.js"></script>
#         <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
#         <h2>Association of Lung Cancer Imaging With Genomic and Clinical Data</h2>
#         <p>A database that connects these feature vectors to various forms of genomic and clinical data and visualize those associations in premalignant/malignant lesions.</p>
#         <script src="Scripts/ScrollableTablePlugin_1.0_min.js" type="text/javascript"></script>
#         <script type="text/javascript"></script>
#         <style>
#             .navbar {
#                 overflow: hidden;
#                 background-color: #008080;
#                 font-family: Arial, Helvetica, sans-serif;
#                 }
#             .navbar a {
#                 float: left;
#                 font-size: 16px;
#                 color: white;
#                 text-align: center;
#                 padding: 14px 16px;
#                 text-decoration: none;
#                 }
#             .dropdown {
#                 float: left;
#                 overflow: hidden;
#                 }
#                 .dropdown .dropbtn {
#                 cursor: pointer;
#                 font-size: 16px;
#                 border: none;
#                 outline: none;
#                 color: white;
#                 padding: 14px 16px;
#                 background-color: inherit;
#                 font-family: inherit;
#                 margin: 0;
#                 }
#                 .navbar a:hover, .dropdown:hover .dropbtn, .dropbtn:focus {
#                 background-color: #008B8B;
#                 }
#                 .show {
#                 display: block;
#                 }
#             * {box-sizing: border-box;}
#             .row {
#                 margin-left:-5px;
#                 margin-right:-5px;
#                 }
#             .column {
#                 float: left;
#                 width: 40%;
#                 padding: 15px;
#                 }
#             /* Clearfix (clear floats) */
#                 .row::after {
#                 content: "";
#                 clear: both;
#                 display: table;
#                 }
#             table {
#                 border-collapse: collapse;
#                 border-spacing: 0;
#                 width: 80%;
#                 border: 1px solid #ddd;
#                 }
#               th, td {
#                 text-align: left;
#                 padding: 16px;
#                 }
#             tr:nth-child(even) {
#                 background-color: #F2F2F2;
#                 }
#         </style>
#     </head>
#     </head>
#     <body>
#         <div class="navbar">
#             <a href="#home">Home</a>
#             <a href="#help">Help</a>
#         </div>
#         <br><br>
#         Sample Type:
#         <select name="sampletype" id="sampletype">
#         <option value="" selected="selected">Choose the Sample type </option>
#         <option value="Biopsy">Biopsy</option>
#         <option value="Brush">Brush</option>
#         <option value="">- All -</option>
#         </select>
#         <br><br>
#         Cohort:
#         <select name="cohorttype" id="cohorttype">
#         <option value="" selected="selected">Choose the Cohort type </option>
#         <option value="Discovery">Discovery</option>
#         <option value="Validation">Validation</option>
#         <option value="">- All -</option>
#         </select>
#         <br><br>
#         Genomic Smoking Status:
#         <select name="status" id="status">
#         <option value="" selected="selected">Choose the Smoking Status type </option>
#         <option value="Current">Current</option>
#         <option value="Former">Former</option>
#         <option value="">- All -</option>
#         </select>
#         <br><br>
#         Previous Lung Cancer History:
#         <select name="LC_history" id="LC_history">
#         <option value="" selected="selected">Choose the Lung Cancer History type </option>
#         <option value="Yes">Yes</option>
#         <option value="No">No</option>
#         <option value="">- All -</option>
#         </select>
#         <br><br>
#         High Risk Lung Cancer Job:
#         <select name="LC_job" id="LC_job">
#         <option value="" selected="selected">Choose Lung Cancer Job type </option>
#         <option value="Yes">Yes</option>
#         <option value="No">No</option>
#         <option value="">- All -</option>
#         </select>
#         <br><br>
#         Asbestos Exposure:
#         <select name="AB_exp" id="AB_exp">
#         <option value="" selected="selected">Choose the Asebestos Exposure type </option>
#         <option value="Yes">Yes</option>
#         <option value="No">No</option>
#         <option value="">- All -</option>
#         </select>
#         <input type="button" id="save_valu" name="save_value" value="Submit" />
#         <div id ="writ"></div>
#         <script>
#             $(document).ready(function(){
#                 $("#writ").append(`<h1>in</h1>`);
#                 $('#save_valu').click(function() {
#                     $("#writ").append(`<h1>in2</h1>`);
#                     var sampletype = $("#sampletype").val();
#                     let cohorttype = $("#cohorttype").val();
#                     let status = $("#status").val();
#                     let LC_history = $("#LC_history").val();
#                     let LC_job = $("#LC_job").val();
#                     let AB_exp = $("#AB_exp").val();
#                     $("#writ").append(`<h1>sampletype: ${document.getElementById("sampletype").value}</h1>`);
#                     $("#writ").append(`<h1>cohorttype: ${cohorttype}</h1>`);
#                     $("#writ").append(`<h1>status: ${status}</h1>`);
#                     $("#writ").append(`<h1>LC_history: ${LC_history}</h1>`);
#                     $("#writ").append(`<h1>LC_job: ${LC_job}</h1>`);
#                     $("#writ").append(`<h1>AB_exp: ${AB_exp}</h1>`);
#             ;});});
#         </script>
#     </body>
# </html>

# %%
# %%html
# <!DOCTYPE html>
# <html>
#    <head>
#       <meta name="viewport" content="width=device-width, initial-scale=1">
#       <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
#       <style>
#          h2 {
#          padding: 60px;
#          text-align: center;
#          background: #1ABC9C;
#          color: white;
#          font-size: 30px;
#          }
#       </style>
#       <h2>Association of Lung Cancer Imaging With Genomic and Clinical Data</h2>
#       <p>A database that connects these feature vectors to various forms of genomic and clinical data and visualize those associations in premalignant/malignant lesions.</p>
#       <script src="Scripts/ScrollableTablePlugin_1.0_min.js" type="text/javascript"></script>
#       <script type="text/javascript"></script>
#       <meta charset="utf-8" />
#       </script>
#       <script src="https://code.jquery.com/jquery-3.4.1.js"></script>
#       <style>
#          .navbar {
#          overflow: hidden;
#          background-color: #008080;
#          font-family: Arial, Helvetica, sans-serif;
#          }
#          .navbar a {
#          float: left;
#          font-size: 16px;
#          color: white;
#          text-align: center;
#          padding: 14px 16px;
#          text-decoration: none;
#          }
#          .dropdown {
#          float: left;
#          overflow: hidden;
#          }
#          .dropdown .dropbtn {
#          cursor: pointer;
#          font-size: 16px;
#          border: none;
#          outline: none;
#          color: white;
#          padding: 14px 16px;
#          background-color: inherit;
#          font-family: inherit;
#          margin: 0;
#          }
#          .navbar a:hover, .dropdown:hover .dropbtn, .dropbtn:focus {
#          background-color: #008B8B;
#          }
#          .show {
#          display: block;
#          }
#          * {box-sizing: border-box;}
#          .row {
#          margin-left:-5px;
#          margin-right:-5px;
#          }
#          .column {
#          float: left;
#          width: 50%;
#          padding: 15px;
#          }
#          /* Clearfix (clear floats) */
#          .row::after {
#          content: "";
#          clear: both;
#          display: table;
#          }
#          table {
#          border-collapse: collapse;
#          border-spacing: 0;
#          width: 100%;
#          border: 1px solid #ddd;
#          }
#          th, td {
#          text-align: left;
#          padding: 16px;
#          overflow: scroll
#          }
#          tr:nth-child(even) {
#          background-color: #F2F2F2;
#          }
#          table.center {
#          margin-left: auto;
#          margin-right: auto;
#          }
#       </style>
#    </head>
#    <body>
#       <div class="navbar">
#          <a href="#home">Home</a>
#          <a href="#help">Help</a>
#       </div>
#       </div>
#       <br><br>
#       Sample Type:
#       <select name="sampletype" id="sampletype">
#          <option value="" selected="selected">Choose the Sample type </option>
#          <option value="Biopsy">Biopsy</option>
#          <option value="Brush">Brush</option>
#          <option value="">- All -</option>
#       </select>
#       <br><br>
#       Cohort:
#       <select name="cohorttype" id="cohorttype">
#          <option value="" selected="selected">Choose the Cohort type </option>
#          <option value="Discovery">Discovery</option>
#          <option value="Validation">Validation</option>
#          <option value="">- All -</option>
#       </select>
#       <br><br>
#       Gender:
#       <select name="gender_type" id="gender_type">
#          <option value="" selected="selected">Choose a gender type </option>
#          <option value="Male">Male</option>
#          <option value="Female">Female</option>
#          <option value="">- All -</option>
#       </select>
#       <br><br>
#       Genomic Smoking Status:
#       <select name="status" id="status">
#          <option value="" selected="selected">Choose the Smoking Status type </option>
#          <option value="Current">Current</option>
#          <option value="Former">Former</option>
#          <option value="">- All -</option>
#       </select>
#       <br><br>
#       Previous Lung Cancer History:
#       <select name="LC_history" id="LC_history">
#          <option value="" selected="selected">Choose the Lung Cancer History type </option>
#          <option value="Yes">Yes</option>
#          <option value="No">No</option>
#          <option value="">- All -</option>
#       </select>
#       <br><br>
#       High Risk Lung Cancer Job:
#       <select name="LC_job" id="LC_job">
#          <option value="" selected="selected">Choose Lung Cancer Job type </option>
#          <option value="Yes">Yes</option>
#          <option value="No">No</option>
#          <option value="">- All -</option>
#       </select>
#       <br><br>
#       Asbestos Exposure:
#       <select name="AB_exp" id="AB_exp">
#          <option value="" selected="selected">Choose the Asebestos Exposure type </option>
#          <option value="Yes">Yes</option>
#          <option value="No">No</option>
#          <option value="">- All -</option>
#       </select>
#       <br><br>
#       <div class="row">
#          <div class="column">
#             <table id="MolecularSubtype">
#                <caption>Molecular Subtype</caption>
#                <tbody>
#                   <tr>
#                      <td><input name="MolecularSubtype[]" id="Normal" class="MolecularSubtype" type="checkbox" value="Normal"/></td>
#                      <td>Normal</td>
#                   </tr>
#                   <tr>
#                      <td><input name="MolecularSubtype[]" id="Secretory" class="MolecularSubtype" type="checkbox" value="Secretory"/></td>
#                      <td>Secretory</td>
#                   </tr>
#                   <tr>
#                      <td><input name="MolecularSubtype[]" id="Proliferative" class="MolecularSubtype" type="checkbox" value="Proliferative"/></td>
#                      <td>Proliferative</td>
#                   </tr>
#                   <tr>
#                      <td><input name="MolecularSubtype[]" id="Inflammatory" class="MolecularSubtype" type="checkbox" value="Inflammatory"/></td>
#                      <td>Inflammatory</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="column">
#             <div><h3 style="text-align:center;">Dysplasia Grade</h3></div>
#             <div class="column" style="height:250px; overflow-y: scroll;">
#             <table id="DysplasiaGrade">
#                <tbody>
#                   <tr>
#                      <td><input name="DysplasiaGrade[]" id="Normal" class="DysplasiaGrade" type="checkbox" value="Normal"/></td>
#                      <td>Normal</td>
#                   </tr>
#                   <tr>
#                      <td><input name="DysplasiaGrade[]" id="MildD" class="DysplasiaGrade" type="checkbox" value="MildD"/></td>
#                      <td>MildD</td>
#                   </tr>
#                   <tr>
#                      <td><input name="DysplasiaGrade[]" id="ModD" class="DysplasiaGrade" type="checkbox" value="ModD"/></td>
#                      <td>ModD</td>
#                   </tr>
#                   <tr>
#                      <td><input name="DysplasiaGrade[]" id="SevD" class="DysplasiaGrade" type="checkbox" value="SevD"/></td>
#                      <td>SevD</td>
#                   </tr>
#                   <tr>
#                      <td><input name="DysplasiaGrade[]" id="Metaplasia" class="DysplasiaGrade" type="checkbox" value="Metaplasia"/></td>
#                      <td>Metaplasia</td>
#                   </tr>
#                   <tr>
#                      <td><input name="DysplasiaGrade[]" id="Hyperplasia" class="DysplasiaGrade" type="checkbox" value="Hyperplasia"/></td>
#                      <td>Hyperplasia</td>
#                   </tr>
#                   <tr>
#                      <td><input name="DysplasiaGrade[]" id="UNK" class="DysplasiaGrade" type="checkbox" value="UNK"/></td>
#                      <td>UNK</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#       </div>
#       <div class="row">
#          <div class="column">
#             <table id="TCGASubtype">
#                <caption>TCGA Subtype</caption>
#                <tbody>
#                   <tr>
#                      <td><input name="TCGASubtype[]" id="Basal" class="TCGASubtype" type="checkbox" value="Basal"/></td>
#                      <td>Basal</td>
#                   </tr>
#                   <tr>
#                      <td><input name="TCGASubtype[]" id="Classical" class="TCGASubtype" type="checkbox" value="Classical"/></td>
#                      <td>Classical</td>
#                   </tr>
#                   <tr>
#                      <td><input name="TCGASubtype[]" id="Primitive" class="TCGASubtype" type="checkbox" value="Primitive"/></td>
#                      <td>Primitive</td>
#                   </tr>
#                   <tr>
#                      <td><input name="TCGASubtype[]" id="Secretory" class="TCGASubtype" type="checkbox" value="Secretory"/></td>
#                      <td>Secretory</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#          <div class="column">
#             <table id="AgeatBaseline">
#                <caption>Age at Baseline</caption>
#                <tbody>
#                   <tr>
#                      <td><input name="AgeatBaseline[]" id="50.0-60.0" class="AgeatBaseline" type="checkbox" value="50"/></td>
#                      <td>50.0-60.0</td>
#                   </tr>
#                   <tr>
#                      <td><input name="AgeatBaseline[]" id="60.0-70.0" class="AgeatBaseline" type="checkbox" value="60"/></td>
#                      <td>60.0-70.0</td>
#                   </tr>
#                   <tr>
#                      <td><input name="AgeatBaseline[]" id="70.0-80.0" class="AgeatBaseline" type="checkbox" value="70"/></td>
#                      <td>70.0-80.0</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#       </div>
#       <div class="row">
#          <div class="column">
#             <table id="Location">
#                <caption>Location</caption>
#                <tbody>
#                   <tr>
#                      <td><input name="Location[]" id="Basal" class="Location" type="checkbox" value="Basal"/></td>
#                      <td>Basal</td>
#                   </tr>
#                </tbody>
#             </table>
#          </div>
#       </div>
#       <div><input type="button" id="save_value" name="save_value" value="Submit" /></div>
#       <div id = "write"></div>
#       <script>
#          $(document).ready(function(){
#              $('#save_value').click(function() {
#                  var MolecularSubtype = []
#                  var DysplasiaGrade = []
#                  var TCGASubtype = []
#                  var AgeatBaseline = []
#                  var Location = []
#                  var i = 0
#                  $('.MolecularSubtype:checked').each(function(i) {
#                      MolecularSubtype[i++] = $(this).val();});
#                  $('.DysplasiaGrade:checked').each(function(i) {
#                      DysplasiaGrade[i++] = $(this).val();});
#                  $('.TCGASubtype:checked').each(function(i) {
#                      TCGASubtype[i++] = $(this).val();});
#                  $('.AgeatBaseline:checked').each(function(i) {
#                      AgeatBaseline[i++] = $(this).val();});
#                  $('.Location:checked').each(function(i) {
#                      Location[i++] = $(this).val();});
#                  $("#write").append(`<h1>MolecularSubtype: ${MolecularSubtype}</h1>`)
#                  $("#write").append(`<h1>Dysplasia Grade: ${DysplasiaGrade}</h1>`)
#                  $("#write").append(`<h1>TCGA Subtype: ${TCGASubtype}</h1>`)
#                  $("#write").append(`<h1>Age at Baseline: ${AgeatBaseline}</h1>`)
#                  $("#write").append(`<h1>Location: ${Location}</h1>`)
#              ;});});
#       </script>
#    </body>
# </html>

# %%
#!/usr/bin/env python3
#Query the miRNA database through the browser using a cgi program

import pymysql
import cgi
import cgitb
import json

#the next line is useful for debugging
#it causes errors during execution to be sent back to the browser
cgitb.enable()

#retrieve input data from the web server
form = cgi.FieldStorage() 

#next line is always required as first part of http output
print("Content-type: text/html\n")

if (form):
    #establish the connection on bioed
    connection = pymysql.connect(host='bioed.bu.edu',user='Group_H',password='Group_H', db='Group_H',port = 4253)  
    cursor = connection.cursor()
    #get submitted values
    selector = form.getvalue("selector","")

    if (selector == "location"):
        query1 = "select distinct Location_Desc from pcga_annotation order by Location_Desc;"
        #execute query
        try: 
            cursor.execute(query1)
        except pymysql.Error as e: 
            print(e,query1)
        results = cursor.fetchall() 
        #format the output as json object
        print(json.dumps(results))
    
    elif (selector == "primary_diagnosis"):
        query2 = "select distinct primary_diagnosis from TCGA_annotation order by primary_diagnosis;"
        #execute query
        try: 
            cursor.execute(query2)
        except pymysql.Error as e: 
            print(e,query2)
        results = cursor.fetchall() 
        #format the output as json object
        print(json.dumps(results))
    cursor.close()
    connection.close()
# Out:
# <html>
#     <head>
#         <script src="Scripts/ScrollableTablePlugin_1.0_min.js" type="text/javascript"></script>
#         <script type="text/javascript"></script>
#         <meta charset="utf-8" /></script>
#         <script src="https://code.jquery.com/jquery-3.4.1.js"></script>
#         <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
#         <h1>Association of Lung Cancer Imaging With Genomic and Clinical Data</h1>
#         <script src="Scripts/ScrollableTablePlugin_1.0_min.js" type="text/javascript"></script>
#         <script type="text/javascript"></script>
#         <style>
#             h1 {
#                 padding: 60px;
#                 text-align: center;
#                 background: #1ABC9C;
#                 color: white;
#                 font-size: 30px;
#                 }
#             .navbar {
#                 overflow: hidden;
#                 background-color: #008080;
#                 font-family: Arial, Helvetica, sans-serif;
#                 }
#             .navbar a {
#                 float: left;
#                 font-size: 16px;
#                 color: white;
#                 text-align: center;
#                 padding: 14px 16px;
#                 text-decoration: none;
#                 }
#             .dropdown {
#                 float: left;
#                 overflow: hidden;
#                 }
#                 .dropdown .dropbtn {
#                 cursor: pointer;
#                 font-size: 16px;
#                 border: none;
#                 outline: none;
#                 color: white;
#                 padding: 14px 16px;
#                 background-color: inherit;
#                 font-family: inherit;
#                 margin: 0;
#                 }
#                 .navbar a:hover, .dropdown:hover .dropbtn, .dropbtn:focus {
#                 background-color: #008B8B;
#                 }
#                 .show {
#                 display: block;
#                 }
#             * {box-sizing: border-box;}
#             .row {
#                 margin-left:-5px;
#                 margin-right:-5px;
#                 }
#             .column {
#                 float: left;
#                 width: 40%;
#                 padding: 15px;
#                 }
#             /* Clearfix (clear floats) */
#                 .row::after {
#                 content: "";
#                 clear: both;
#                 display: table;
#                 }
#             table {
#                 border-collapse: collapse;
#                 border-spacing: 0;
#                 width: 80%;
#                 border: 1px solid #ddd;
#                 }
#               th, td {
#                 text-align: left;
#                 padding: 16px;
#                 }
#             tr:nth-child(even) {
#                 background-color: #F2F2F2;
#                 }
#         </style>
#     </head>
#     </head>
#     <body>
#         <div class="navbar">
#             <a href="#home">Home</a>
#             <a href="#help">Help</a>
#         </div>
#         <p>A database that connects these feature vectors to various forms of genomic and clinical data and visualize those associations in premalignant/malignant lesions.</p>
#         <br><br>
#         Sample Type:
#         <select name="sampletype" id="sampletype">
#         <option value="" selected="selected">Choose the Sample type </option>
#         <option value="Biopsy">Biopsy</option>
#         <option value="Brush">Brush</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         Cohort:
#         <select name="cohorttype" id="cohorttype">
#         <option value="" selected="selected">Choose the Cohort type </option>
#         <option value="Discovery">Discovery</option>
#         <option value="Validation">Validation</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         Genomic Smoking Status:
#         <select name="status" id="status">
#         <option value="" selected="selected">Choose the Smoking Status type </option>
#         <option value="Current">Current</option>
#         <option value="Former">Former</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         Previous Lung Cancer History:
#         <select name="LC_history" id="LC_history">
#         <option value="" selected="selected">Choose the Lung Cancer History type </option>
#         <option value="Yes">Yes</option>
#         <option value="No">No</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         High Risk Lung Cancer Job:
#         <select name="LC_job" id="LC_job">
#         <option value="" selected="selected">Choose Lung Cancer Job type </option>
#         <option value="Yes">Yes</option>
#         <option value="No">No</option>
#         <option value="">- Both -</option>
#         </select>
#         <br><br>
#         Asbestos Exposure:
#         <select name="AB_exp" id="AB_exp">
#         <option value="" selected="selected">Choose the Asebestos Exposure type </option>
#         <option value="Yes">Yes</option>
#         <option value="No">No</option>
#         <option value="">- Both -</option>
#         </select><br></br>
#         <input type="button" id="save_value" name="save_value" value="Save" />
#         <div id ="write1"></div>
#     <div class="row">
#     <div class="column">
#          <table id="MolecularSubtype">
#                 <caption>Molecular Subtype</caption>
#                 <tbody>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Normal" class="MolecularSubtype" type="checkbox" value="Normal"/></td>
#                         <td>Normal</td>
#                     </tr>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Secretory" class="MolecularSubtype" type="checkbox" value="Secretory"/></td>
#                         <td>Secretory</td>
#                     </tr>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Proliferative" class="MolecularSubtype" type="checkbox" value="Proliferative"/></td>
#                         <td>Proliferative</td>
#                     </tr>
#                     <tr>
#                         <td><input name="MolecularSubtype[]" id="Inflammatory" class="MolecularSubtype" type="checkbox" value="Inflammatory"/></td>
#                         <td>Inflammatory</td>
#                     </tr>
#                 </tbody>
#         </table>
#     </div>
#     <div><h3 style="text-align:center;">Dysplasia Grade</h3></div>
#     <div class="column" style="height:250px; overflow-y: scroll;">
#         <table id="DysplasiaGrade">
#                 <tbody>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="Normal" class="DysplasiaGrade" type="checkbox" value="Normal"/></td>
#                         <td>Normal</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="MildD" class="DysplasiaGrade" type="checkbox" value="MildD"/></td>
#                         <td>MildD</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="ModD" class="DysplasiaGrade" type="checkbox" value="ModD"/></td>
#                         <td>ModD</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="SevD" class="DysplasiaGrade" type="checkbox" value="SevD"/></td>
#                         <td>SevD</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="Metaplasia" class="DysplasiaGrade" type="checkbox" value="Metaplasia"/></td>
#                         <td>Metaplasia</td>
#                     </tr>
#                     <tr>
#                         <td><input name="DysplasiaGrade[]" id="Hyperplasia" class="DysplasiaGrade" type="checkbox" value="Hyperplasia"/></td>
#                         <td>Hyperplasia</td>
#                     </tr>
#                     <tr>
#                         <td><input name="Dyspla
